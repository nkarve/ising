# %%
import numpy as np
import matplotlib.pyplot as plt
from ising import plot_macroscopic

plot_macroscopic(np.linspace(1.53, 3.28, 20), int(10e7), int(10e6), 32)
# Out:
# Running batch 1
# Running batch 2
# Running batch 3
# Running batch 4
# Running batch 5
# Running batch 6
# Running batch 7
# Running batch 8
# Running batch 9
# Running batch 10
# Running batch 11
# Running batch 12
# Running batch 13
# Running batch 14
# Running batch 15
# Running batch 16
# Running batch 17
# Running batch 18
# Running batch 19
# Running batch 20
# [-1.94699979 -1.91871567 -1.88966199 -1.84865815 -1.82749522 -1.74466492
#  -1.66312355 -1.5838571  -1.42528306 -1.28575961 -1.14436531 -1.06399197
#  -1.00901156 -0.94983934 -0.90167143 -0.85469435 -0.82625539 -0.7727154
#  -0.75330175 -0.71634371]
# [-9.84701571e-01  9.77864679e-01 -9.68605613e-01 -9.55882619e-01
#  -9.38523602e-01  9.14815375e-01 -8.74350443e-01 -8.19004229e-01
#   4.23299658e-01  1.43708639e-01  2.00577043e-02  1.78539654e-02
#   2.05415963e-02  1.24215648e-02 -1.46813477e-04 -8.52915469e-03
#   1.41523633e-03  1.39844336e-04 -7.19608262e-03 -2.61409551e-03]
# ...
